# %% [markdown]
# # Prepare

# %%
import os # for file handling
import pathlib # for reading files
import pandas as pd # for reading csv files
import numpy as np # for numerical operations
from PIL import Image # for opening images
import shutil # for moving files
import matplotlib.pyplot as plt # for plotting

import tensorflow as tf # for deep learning
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# Check GPU

# %%
print("TensorFlow version:", tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Physical Devices:", tf.config.list_physical_devices('GPU'))


from tensorflow.python.client import device_lib

def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

print(get_available_devices())
# Out:
# TensorFlow version: 2.10.1
# Num GPUs Available:  1
# Physical Devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ['/device:CPU:0', '/device:GPU:0']

# %% [markdown]
# # Load Data using Keras utility

# %%
data_dir = pathlib.Path('C:\\Users\\mirela\\Documents\\gitRepos\\CatWatcher\\cats_approach_training_2024_05_19\\categories')

# %% [markdown]
# Define parameters for loader

# %%
batch_size = 32
#Larger batches also provide a more accurate estimate of the gradient, but they require more memory.

img_height = 180 # Using the actual sizes takes too long for training.
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 21306 files belonging to 2 classes.
# Using 17045 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 21306 files belonging to 2 classes.
# Using 4261 files for validation.

# %% [markdown]
# You can find the class names in the `class_names` attribute on these datasets.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['n', 'y']

# %% [markdown]
# # Visualize the Data

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# An image can be represented as a 3-D tensor. For a color image, the dimensions might correspond to height, width, and color channels (RGB). The `image_batch` is a tensor of the shape `(32, 480, 480, 3)`. This is a batch of 32 images of shape `480x480x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.
#
# You can call `.numpy()` on either of these tensors to convert them to a `numpy.ndarray`.

# %% [markdown]
# # Configure the dataset for performance
#
# Let's make sure to use buffered prefetching so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data:
#
# - `Dataset.cache` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
# - `Dataset.prefetch` overlaps data preprocessing and model execution while training.
#
# Interested readers can learn more about both methods, as well as how to cache data to disk in the *Prefetching* section of the [Better performance with the tf.data API](../../guide/data_performance.ipynb) guide.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # A basic Keras model with Dropout Layers

# %% [markdown]
# ### Create the model

# %% [markdown]
# The [Sequential](https://www.tensorflow.org/guide/keras/sequential_model) model consists of three convolution blocks (`tf.keras.layers.Conv2D`) with a max pooling layer (`tf.keras.layers.MaxPooling2D`) in each of them. There's a fully-connected layer (`tf.keras.layers.Dense`) with 128 units on top of it that is activated by a ReLU activation function (`'relu'`). This model has not been tuned in any way—the goal is to show you the mechanics using the datasets you just created. To learn more about image classification, visit the [Image classification](../images/classification.ipynb) tutorial.

# %%
num_classes = len(class_names)
print("Number of classes:", num_classes)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(1, activation='sigmoid') # Binary classification
])

model.compile(
  optimizer='adam',
  loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
  metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

model.summary()
# Out:
# Number of classes: 2
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  dropout (Dropout)           (None, 90, 90, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 45, 45, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 64)        0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3,988,769
# Trainable params: 3,988,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[early_stopping, model_checkpoint, reduce_lr]
)
# Out:
# Epoch 1/500
# 533/533 [==============================] - 8s 8ms/step - loss: 0.4921 - accuracy: 0.7420 - val_loss: 0.4220 - val_accuracy: 0.7946 - lr: 0.0010
# Epoch 2/500
# 533/533 [==============================] - 3s 7ms/step - loss: 0.3908 - accuracy: 0.7944 - val_loss: 0.3638 - val_accuracy: 0.8169 - lr: 0.0010
# Epoch 3/500
# 533/533 [==============================] - 3s 7ms/step - loss: 0.3545 - accuracy: 0.8180 - val_loss: 0.3331 - val_accuracy: 0.8331 - lr: 0.0010
# Epoch 4/500
# 533/533 [==============================] - 3s 7ms/step - loss: 0.3231 - accuracy: 0.8361 - val_loss: 0.2998 - val_accuracy: 0.8566 - lr: 0.0010
# Epoch 5/500
# 533/533 [==============================] - 3s 7ms/step - loss: 0.3005 - accuracy: 0.8535 - val_loss: 0.2925 - val_accuracy: 0.8561 - lr: 0.0010
# Epoch 6/500
# 533/533 [==============================] - 3s 7ms/step - loss: 0.2719 - accuracy: 0.8655 - val_loss: 0.2839 - val_accuracy: 0.8660 - lr: 0.0010
# Epoch 7/500
# 533/533 [==============================] - 3s 7ms/step - loss: 0.2545 - accuracy: 0.8747 - val_loss: 0.2622 - val_accuracy: 0.8810 - lr: 0.0010
# Epoch 8/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.2344 - accuracy: 0.8856 - val_loss: 0.2534 - val_accuracy: 0.8920 - lr: 0.0010
# Epoch 9/500
# 533/533 [==============================] - 3s 7ms/step - loss: 0.2151 - accuracy: 0.8923 - val_loss: 0.2375 - val_accuracy: 0.8916 - lr: 0.0010
# Epoch 10/500
# 533/533 [==============================] - 3s 7ms/step - loss: 0.1999 - accuracy: 0.8990 - val_loss: 0.2275 - val_accuracy: 0.9017 - lr: 0.0010
# Epoch 11/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1899 - accuracy: 0.9043 - val_loss: 0.2392 - val_accuracy: 0.8960 - lr: 0.0010
# Epoch 12/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1758 - accuracy: 0.9134 - val_loss: 0.2457 - val_accuracy: 0.8977 - lr: 0.0010
# Epoch 13/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1640 - accuracy: 0.9189 - val_loss: 0.2233 - val_accuracy: 0.9064 - lr: 0.0010
# Epoch 14/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1590 - accuracy: 0.9210 - val_loss: 0.2527 - val_accuracy: 0.9031 - lr: 0.0010
# Epoch 15/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1559 - accuracy: 0.9243 - val_loss: 0.2234 - val_accuracy: 0.9101 - lr: 0.0010
# Epoch 16/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1469 - accuracy: 0.9294 - val_loss: 0.2287 - val_accuracy: 0.9078 - lr: 0.0010
# Epoch 17/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1447 - accuracy: 0.9298 - val_loss: 0.2175 - val_accuracy: 0.9108 - lr: 0.0010
# Epoch 18/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1367 - accuracy: 0.9344 - val_loss: 0.2374 - val_accuracy: 0.9134 - lr: 0.0010
# Epoch 19/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1307 - accuracy: 0.9379 - val_loss: 0.2497 - val_accuracy: 0.9120 - lr: 0.0010
# Epoch 20/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1256 - accuracy: 0.9388 - val_loss: 0.2301 - val_accuracy: 0.9153 - lr: 0.0010
# Epoch 21/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1209 - accuracy: 0.9417 - val_loss: 0.2624 - val_accuracy: 0.9094 - lr: 0.0010
# Epoch 22/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1218 - accuracy: 0.9437 - val_loss: 0.2488 - val_accuracy: 0.9115 - lr: 0.0010
# Epoch 23/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1048 - accuracy: 0.9472 - val_loss: 0.2529 - val_accuracy: 0.9153 - lr: 5.0000e-04
# Epoch 24/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.1039 - accuracy: 0.9481 - val_loss: 0.2534 - val_accuracy: 0.9169 - lr: 5.0000e-04
# Epoch 25/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.0997 - accuracy: 0.9515 - val_loss: 0.2642 - val_accuracy: 0.9195 - lr: 5.0000e-04
# Epoch 26/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.0945 - accuracy: 0.9539 - val_loss: 0.2746 - val_accuracy: 0.9216 - lr: 5.0000e-04
# Epoch 27/500
# 533/533 [==============================] - 3s 6ms/step - loss: 0.0929 - accuracy: 0.9553 - val_loss: 0.2943 - val_accuracy: 0.9197 - lr: 5.0000e-04

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(27) # adjust this to the number of epochs

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Add Data Augmentation Layer

# %% [markdown]
# Overfitting generally occurs when there are a small number of training examples. [Data augmentation](./data_augmentation.ipynb) takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.
#
# You will implement data augmentation using the following Keras preprocessing layers: `tf.keras.layers.RandomFlip`, `tf.keras.layers.RandomRotation`, and `tf.keras.layers.RandomZoom`. These can be included inside your model like other layers, and run on the GPU.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# ## Visualize Augmented Data

# %% [markdown]
# Visualize a few augmented examples by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x000002B3943639A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x000002B3943637F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# ## Create Model with Data Augmentation Layer

# %%
num_classes = len(class_names)
print("Number of classes:", num_classes)

model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),# input shape already defined in data_augmentation layer
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.25),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(1, activation='sigmoid') # Binary classification
])

model.compile(
  optimizer='adam',
  loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
  metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

model.summary()
# Out:
# Number of classes: 2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  dropout (Dropout)           (None, 90, 90, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 45, 45, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 64)        0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3,988,769
# Trainable params: 3,988,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[early_stopping, model_checkpoint, reduce_lr]
)
# Out:
# Epoch 1/500
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 533/533 [==============================] - 53s 97ms/step - loss: 0.4921 - accuracy: 0.7423 - val_loss: 0.4551 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 2/500
# 533/533 [==============================] - 52s 98ms/step - loss: 0.4373 - accuracy: 0.7614 - val_loss: 0.4166 - val_accuracy: 0.7756 - lr: 0.0010
# Epoch 3/500
# 533/533 [==============================] - 51s 95ms/step - loss: 0.4131 - accuracy: 0.7791 - val_loss: 0.3981 - val_accuracy: 0.8113 - lr: 0.0010
# Epoch 4/500
# 533/533 [==============================] - 51s 95ms/step - loss: 0.3938 - accuracy: 0.7944 - val_loss: 0.3719 - val_accuracy: 0.8268 - lr: 0.0010
# Epoch 5/500
# 533/533 [==============================] - 51s 95ms/step - loss: 0.3733 - accuracy: 0.8121 - val_loss: 0.3353 - val_accuracy: 0.8444 - lr: 0.0010
# Epoch 6/500
# 533/533 [==============================] - 51s 96ms/step - loss: 0.3474 - accuracy: 0.8273 - val_loss: 0.3094 - val_accuracy: 0.8467 - lr: 0.0010
# Epoch 7/500
# 533/533 [==============================] - 51s 96ms/step - loss: 0.3371 - accuracy: 0.8360 - val_loss: 0.2844 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 8/500
# 533/533 [==============================] - 51s 95ms/step - loss: 0.3195 - accuracy: 0.8457 - val_loss: 0.2850 - val_accuracy: 0.8733 - lr: 0.0010
# Epoch 9/500
# 533/533 [==============================] - 52s 97ms/step - loss: 0.3143 - accuracy: 0.8494 - val_loss: 0.2762 - val_accuracy: 0.8744 - lr: 0.0010
# Epoch 10/500
# 533/533 [==============================] - 52s 98ms/step - loss: 0.3099 - accuracy: 0.8524 - val_loss: 0.3076 - val_accuracy: 0.8613 - lr: 0.0010
# Epoch 11/500
# 533/533 [==============================] - 51s 97ms/step - loss: 0.3030 - accuracy: 0.8583 - val_loss: 0.2773 - val_accuracy: 0.8742 - lr: 0.0010
# Epoch 12/500
# 533/533 [==============================] - 52s 98ms/step - loss: 0.2907 - accuracy: 0.8649 - val_loss: 0.2649 - val_accuracy: 0.8810 - lr: 0.0010
# Epoch 13/500
# 533/533 [==============================] - 52s 97ms/step - loss: 0.2838 - accuracy: 0.8680 - val_loss: 0.2563 - val_accuracy: 0.8864 - lr: 0.0010
# Epoch 14/500
# 533/533 [==============================] - 51s 96ms/step - loss: 0.2836 - accuracy: 0.8658 - val_loss: 0.2546 - val_accuracy: 0.8843 - lr: 0.0010
# Epoch 15/500
# 533/533 [==============================] - 52s 97ms/step - loss: 0.2787 - accuracy: 0.8678 - val_loss: 0.2427 - val_accuracy: 0.8949 - lr: 0.0010
# Epoch 16/500
# 533/533 [==============================] - 52s 97ms/step - loss: 0.2715 - accuracy: 0.8729 - val_loss: 0.2341 - val_accuracy: 0.9007 - lr: 0.0010
# Epoch 17/500
# 533/533 [==============================] - 51s 96ms/step - loss: 0.2723 - accuracy: 0.8746 - val_loss: 0.2345 - val_accuracy: 0.8965 - lr: 0.0010
# Epoch 18/500
# 533/533 [==============================] - 52s 98ms/step - loss: 0.2636 - accuracy: 0.8784 - val_loss: 0.2332 - val_accuracy: 0.9005 - lr: 0.0010
# Epoch 19/500
# 533/533 [==============================] - 52s 97ms/step - loss: 0.2614 - accuracy: 0.8774 - val_loss: 0.2326 - val_accuracy: 0.9054 - lr: 0.0010
# Epoch 20/500
# 533/533 [==============================] - 51s 97ms/step - loss: 0.2560 - accuracy: 0.8812 - val_loss: 0.2387 - val_accuracy: 0.9073 - lr: 0.0010
# Epoch 21/500
# 533/533 [==============================] - 52s 97ms/step - loss: 0.2576 - accuracy: 0.8805 - val_loss: 0.2308 - val_accuracy: 0.9028 - lr: 0.0010
# Epoch 22/500
# 533/533 [==============================] - 51s 96ms/step - loss: 0.2505 - accuracy: 0.8850 - val_loss: 0.2213 - val_accuracy: 0.9047 - lr: 0.0010
# Epoch 23/500
# 533/533 [==============================] - 52s 98ms/step - loss: 0.2522 - accuracy: 0.8846 - val_loss: 0.2348 - val_accuracy: 0.9042 - lr: 0.0010
# Epoch 24/500
# 533/533 [==============================] - 51s 95ms/step - loss: 0.2451 - accuracy: 0.8865 - val_loss: 0.2306 - val_accuracy: 0.9000 - lr: 0.0010
# Epoch 25/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.2426 - accuracy: 0.8880 - val_loss: 0.2165 - val_accuracy: 0.9132 - lr: 0.0010
# Epoch 26/500
# 533/533 [==============================] - 52s 97ms/step - loss: 0.2424 - accuracy: 0.8916 - val_loss: 0.2455 - val_accuracy: 0.8949 - lr: 0.0010
# Epoch 27/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.2397 - accuracy: 0.8896 - val_loss: 0.2225 - val_accuracy: 0.9035 - lr: 0.0010
# Epoch 28/500
# 533/533 [==============================] - 52s 98ms/step - loss: 0.2373 - accuracy: 0.8919 - val_loss: 0.2202 - val_accuracy: 0.9118 - lr: 0.0010
# Epoch 29/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.2371 - accuracy: 0.8898 - val_loss: 0.2145 - val_accuracy: 0.9111 - lr: 0.0010
# Epoch 30/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.2350 - accuracy: 0.8925 - val_loss: 0.2126 - val_accuracy: 0.9061 - lr: 0.0010
# Epoch 31/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.2326 - accuracy: 0.8928 - val_loss: 0.2100 - val_accuracy: 0.9127 - lr: 0.0010
# Epoch 32/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.2318 - accuracy: 0.8942 - val_loss: 0.2162 - val_accuracy: 0.9150 - lr: 0.0010
# Epoch 33/500
# 533/533 [==============================] - 51s 96ms/step - loss: 0.2293 - accuracy: 0.8958 - val_loss: 0.2085 - val_accuracy: 0.9146 - lr: 0.0010
# Epoch 34/500
# 533/533 [==============================] - 52s 98ms/step - loss: 0.2318 - accuracy: 0.8968 - val_loss: 0.2182 - val_accuracy: 0.9089 - lr: 0.0010
# Epoch 35/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.2206 - accuracy: 0.8989 - val_loss: 0.2208 - val_accuracy: 0.9111 - lr: 0.0010
# Epoch 36/500
# 533/533 [==============================] - 54s 101ms/step - loss: 0.2247 - accuracy: 0.8974 - val_loss: 0.2113 - val_accuracy: 0.9174 - lr: 0.0010
# Epoch 37/500
# 533/533 [==============================] - 72s 135ms/step - loss: 0.2213 - accuracy: 0.8992 - val_loss: 0.2055 - val_accuracy: 0.9120 - lr: 0.0010
# Epoch 38/500
# 533/533 [==============================] - 78s 147ms/step - loss: 0.2195 - accuracy: 0.8992 - val_loss: 0.2193 - val_accuracy: 0.9054 - lr: 0.0010
# Epoch 39/500
# 533/533 [==============================] - 81s 151ms/step - loss: 0.2164 - accuracy: 0.9053 - val_loss: 0.2028 - val_accuracy: 0.9132 - lr: 0.0010
# Epoch 40/500
# 533/533 [==============================] - 81s 153ms/step - loss: 0.2181 - accuracy: 0.8997 - val_loss: 0.2078 - val_accuracy: 0.9169 - lr: 0.0010
# Epoch 41/500
# 533/533 [==============================] - 83s 156ms/step - loss: 0.2166 - accuracy: 0.9016 - val_loss: 0.2107 - val_accuracy: 0.9127 - lr: 0.0010
# Epoch 42/500
# 533/533 [==============================] - 84s 158ms/step - loss: 0.2193 - accuracy: 0.9010 - val_loss: 0.2085 - val_accuracy: 0.9197 - lr: 0.0010
# Epoch 43/500
# 533/533 [==============================] - 82s 153ms/step - loss: 0.2156 - accuracy: 0.9037 - val_loss: 0.2118 - val_accuracy: 0.9120 - lr: 0.0010
# Epoch 44/500
# 533/533 [==============================] - 81s 152ms/step - loss: 0.2087 - accuracy: 0.9038 - val_loss: 0.2141 - val_accuracy: 0.9143 - lr: 0.0010
# Epoch 45/500
# 533/533 [==============================] - 80s 149ms/step - loss: 0.2001 - accuracy: 0.9096 - val_loss: 0.2028 - val_accuracy: 0.9174 - lr: 5.0000e-04
# Epoch 46/500
# 533/533 [==============================] - 64s 120ms/step - loss: 0.1966 - accuracy: 0.9123 - val_loss: 0.2030 - val_accuracy: 0.9211 - lr: 5.0000e-04
# Epoch 47/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1936 - accuracy: 0.9117 - val_loss: 0.2052 - val_accuracy: 0.9202 - lr: 5.0000e-04
# Epoch 48/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1938 - accuracy: 0.9100 - val_loss: 0.1962 - val_accuracy: 0.9226 - lr: 5.0000e-04
# Epoch 49/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1929 - accuracy: 0.9154 - val_loss: 0.1949 - val_accuracy: 0.9270 - lr: 5.0000e-04
# Epoch 50/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1931 - accuracy: 0.9145 - val_loss: 0.1981 - val_accuracy: 0.9214 - lr: 5.0000e-04
# Epoch 51/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1921 - accuracy: 0.9127 - val_loss: 0.2018 - val_accuracy: 0.9249 - lr: 5.0000e-04
# Epoch 52/500
# 533/533 [==============================] - 54s 101ms/step - loss: 0.1921 - accuracy: 0.9098 - val_loss: 0.1911 - val_accuracy: 0.9263 - lr: 5.0000e-04
# Epoch 53/500
# 533/533 [==============================] - 54s 101ms/step - loss: 0.1900 - accuracy: 0.9143 - val_loss: 0.1901 - val_accuracy: 0.9233 - lr: 5.0000e-04
# Epoch 54/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1894 - accuracy: 0.9141 - val_loss: 0.1913 - val_accuracy: 0.9216 - lr: 5.0000e-04
# Epoch 55/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1851 - accuracy: 0.9155 - val_loss: 0.1908 - val_accuracy: 0.9247 - lr: 5.0000e-04
# Epoch 56/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1824 - accuracy: 0.9159 - val_loss: 0.1897 - val_accuracy: 0.9258 - lr: 5.0000e-04
# Epoch 57/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1844 - accuracy: 0.9175 - val_loss: 0.1886 - val_accuracy: 0.9317 - lr: 5.0000e-04
# Epoch 58/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1860 - accuracy: 0.9158 - val_loss: 0.1966 - val_accuracy: 0.9226 - lr: 5.0000e-04
# Epoch 59/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1864 - accuracy: 0.9134 - val_loss: 0.1846 - val_accuracy: 0.9294 - lr: 5.0000e-04
# Epoch 60/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1789 - accuracy: 0.9197 - val_loss: 0.1952 - val_accuracy: 0.9268 - lr: 5.0000e-04
# Epoch 61/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1807 - accuracy: 0.9171 - val_loss: 0.1882 - val_accuracy: 0.9275 - lr: 5.0000e-04
# Epoch 62/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1841 - accuracy: 0.9185 - val_loss: 0.2015 - val_accuracy: 0.9249 - lr: 5.0000e-04
# Epoch 63/500
# 533/533 [==============================] - 53s 100ms/step - loss: 0.1810 - accuracy: 0.9187 - val_loss: 0.2004 - val_accuracy: 0.9174 - lr: 5.0000e-04
# Epoch 64/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1737 - accuracy: 0.9218 - val_loss: 0.1976 - val_accuracy: 0.9209 - lr: 5.0000e-04
# Epoch 65/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1691 - accuracy: 0.9243 - val_loss: 0.1877 - val_accuracy: 0.9268 - lr: 2.5000e-04
# Epoch 66/500
# 533/533 [==============================] - 54s 101ms/step - loss: 0.1698 - accuracy: 0.9232 - val_loss: 0.1904 - val_accuracy: 0.9277 - lr: 2.5000e-04
# Epoch 67/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1715 - accuracy: 0.9203 - val_loss: 0.1936 - val_accuracy: 0.9254 - lr: 2.5000e-04
# Epoch 68/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1676 - accuracy: 0.9234 - val_loss: 0.1991 - val_accuracy: 0.9303 - lr: 2.5000e-04
# Epoch 69/500
# 533/533 [==============================] - 53s 99ms/step - loss: 0.1718 - accuracy: 0.9220 - val_loss: 0.1887 - val_accuracy: 0.9280 - lr: 2.5000e-04

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(69) # adjust this to the number of epochs

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
